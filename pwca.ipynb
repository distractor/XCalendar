# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

# %%
now = datetime.now()

competitions = []
for year in [now.year - 1, now.year, now.year + 1]:
    url = 'http://www.pwca.org/view/tour/' + str(year)
    page_response = requests.get(url)
    page = BeautifulSoup(page_response.content, "html.parser")
    tables = page.find_all(class_ = "views-table")
    
    for table in tables:
        if (table.find('caption').string.find("Selective") != - 1):
            continue
        
        data = table.find_all("td", class_ = "views-field-title")
        comp_names = []
        comp_locations = []
        comp_urls = []
        for comp in data:
            compID = comp.find("a").string
            if (compID.find(" ::: ") == - 1):
                compID = comp.find("a").string.split(" - ")
            else:
                compID = comp.find("a").string.split(" ::: ")
            comp_names.append(compID[0])
            comp_locations.append(compID[1])
            comp_urls.append('http://www.pwca.org/' + comp.find('a').get('href'))

        data = table.find_all(class_ = "date-display-range")
        comp_starts = []
        comp_ends = []
        for comp in data:
            date = comp.contents[0].string.split("/")
            comp_starts.append(datetime.strptime(date[0] + "-" + date[1] + "-" + date[2], '%d-%m-%Y'))
            date = comp.contents[2].string.split("/")
            comp_ends.append(datetime.strptime(date[0] + "-" + date[1] + "-" + date[2], '%d-%m-%Y'))

        for i in range(len(comp_names)):
            competitions.append([comp_names[i], comp_urls[i], comp_locations[i], comp_starts[i], comp_ends[i], 'Paraglider'])

print("----  DONE  ----")
print("%d competitions saved." % len(competitions))
# Out:
# ----  DONE  ----
# 49 competitions saved.

# %%
competitions
# Out:
# [['2018 World Cup - Australia',
#   'http://www.pwca.org//node/36948',
#   'Bright',
#   datetime.datetime(2018, 2, 17, 0, 0),
#   datetime.datetime(2018, 2, 24, 0, 0),
#   'Paraglider'],
#  ['2018 World Cup - Brazil',
#   'http://www.pwca.org//node/37918',
#   'Baixo Guandu',
#   datetime.datetime(2018, 4, 14, 0, 0),
#   datetime.datetime(2018, 4, 21, 0, 0),
#   'Paraglider'],
#  ['2018 World Cup - Italy',
#   'http://www.pwca.org//node/37919',
#   'Gemona',
#   datetime.datetime(2018, 6, 23, 0, 0),
#   datetime.datetime(2018, 6, 30, 0, 0),
#   'Paraglider'],
#  ['2018 World Cup - Bulgaria',
#   'http://www.pwca.org//node/37920',
#   'Sopot',
#   datetime.datetime(2018, 8, 18, 0, 0),
#   datetime.datetime(2018, 8, 25, 0, 0),
#   'Paraglider'],
#  ['2018 World Cup - Turkey',
#   'http://www.pwca.org//node/37921',
#   'Aksaray',
#   datetime.datetime(2018, 9, 8, 0, 0),
#   datetime.datetime(2018, 9, 15, 0, 0),
#   'Paraglider'],
#  ['10th Paragliding World Cup Superfinal',
# ...
